# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
# file_path = 'C:/Users/Gina/Pictures/md/heart_attack_prediction_indonesia.csv'
file_path = './heart_attack_prediction_indonesia.csv' # Path to the dataset
TARGET = "heart_attack"
data = pd.read_csv(
    file_path,
    sep = ',',
    na_values = "."
)

print(f"Originally we have {data.shape[0]} samples and {data.shape[1]} features.")  # Shape returns (nº samples, nº features)
#print(data.describe())
#data.head()

n_samples = 20000
df = data.sample(n=n_samples)
print(f"For this project we have {df.shape[0]} samples and {df.shape[1]} features.")
print(df.describe())
df.head()
# Out:
# Originally we have 158355 samples and 28 features.
# For this project we have 20000 samples and 28 features.
#                 age  hypertension      diabetes  cholesterol_level  \
# count  20000.000000  20000.000000  20000.000000       20000.000000
# mean      54.531550      0.297100      0.197400         199.185100
# std       11.907195      0.456992      0.398047          39.947344
# min       25.000000      0.000000      0.000000         100.000000
# 25%       46.000000      0.000000      0.000000         172.000000
# 50%       55.000000      0.000000      0.000000         199.000000
# 75%       63.000000      1.000000      0.000000         227.000000
# max       90.000000      1.000000      1.000000         350.000000
#
#             obesity  waist_circumference  family_history   sleep_hours  \
# count  20000.000000         20000.000000    20000.000000  20000.000000
# mean       0.249600            93.367800        0.294400      6.480324
# std        0.432792            16.266181        0.455784      1.418308
# min        0.000000            27.000000        0.000000      3.000000
# 25%        0.000000            82.000000        0.000000      5.484661
# 50%        0.000000            93.000000        0.000000      6.510857
# 75%        0.000000           104.000000        1.000000      7.512195
# max        1.000000           153.000000        1.000000      9.000000
#
#        blood_pressure_systolic  blood_pressure_diastolic  fasting_blood_sugar  \
# count             20000.000000              20000.000000         20000.000000
# mean                129.446400                 79.523250           110.614400
# std                  15.032539                  9.977487            27.830186
# min                  69.000000                 42.000000            70.000000
# 25%                 119.000000                 73.000000            89.000000
# 50%                 129.000000                 80.000000           109.000000
# 75%                 140.000000                 86.000000           130.000000
# max                 187.000000                118.000000           228.000000
#
#        cholesterol_hdl  cholesterol_ldl  triglycerides  \
# count     20000.000000     20000.000000   20000.000000
# mean         49.531550       129.302650     149.468750
# std           9.923091        34.779454      49.115999
# min          10.000000       -18.000000      50.000000
# 25%          43.000000       106.000000     115.000000
# 50%          49.000000       130.000000     149.000000
# 75%          56.000000       153.000000     183.000000
# max          89.000000       276.000000     347.000000
#
#        previous_heart_disease  medication_usage  \
# count            20000.000000      20000.000000
# mean                 0.201600          0.498150
# std                  0.401205          0.500009
# min                  0.000000          0.000000
# 25%                  0.000000          0.000000
# 50%                  0.000000          0.000000
# 75%                  0.000000          1.000000
# max                  1.000000          1.000000
#
#        participated_in_free_screening  heart_attack
# count                    20000.000000   20000.00000
# mean                         0.603600       0.39480
# std                          0.489162       0.48882
# min                          0.000000       0.00000
# 25%                          0.000000       0.00000
# 50%                          1.000000       0.00000
# 75%                          1.000000       1.00000
# max                          1.000000       1.00000
#         age  gender region income_level  hypertension  diabetes  \
# 22265    53    Male  Urban       Middle             0         0
# 128501   47  Female  Rural          Low             1         0
# 18232    41    Male  Urban       Middle             0         0
# 36677    76  Female  Rural         High             1         0
# 81985    69  Female  Rural       Middle             0         0
#
#         cholesterol_level  obesity  waist_circumference  family_history  ...  \
# 22265                 158        1                   99               0  ...
# 128501                231        0                  100               1  ...
# 18232                 159        1                  132               0  ...
# 36677                 278        0                   75               0  ...
# 81985                 193        0                   79               0  ...
#
#        blood_pressure_diastolic fasting_blood_sugar cholesterol_hdl  \
# 22265                        89                 164              48
# 128501                       59                 124              63
# 18232                        87                 105              55
# 36677                        82                 123              50
# 81985                        68                  70              35
#
#        cholesterol_ldl triglycerides EKG_results  previous_heart_disease  \
# 22265              202           164    Abnormal                       0
# 128501             114           210      Normal                       0
# 18232              145           188      Normal                       0
# 36677              215           139      Normal                       0
# 81985              155           188      Normal                       0
#
#         medication_usage  participated_in_free_screening  heart_attack
# 22265                  0                               1             1
# 128501                 1                               1             0
# 18232                  0                               1             0
# 36677                  1                               1             0
# 81985                  0                               1             1
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Uni-variate Descriptive Analysis

# %%
df.describe(include = "all")
# Out:
#                  age gender region income_level  hypertension      diabetes  \
# count   20000.000000  20000  20000        20000  20000.000000  20000.000000
# unique           NaN      2      2            3           NaN           NaN
# top              NaN   Male  Urban       Middle           NaN           NaN
# freq             NaN  10372  13084         8991           NaN           NaN
# mean       54.531550    NaN    NaN          NaN      0.297100      0.197400
# std        11.907195    NaN    NaN          NaN      0.456992      0.398047
# min        25.000000    NaN    NaN          NaN      0.000000      0.000000
# 25%        46.000000    NaN    NaN          NaN      0.000000      0.000000
# 50%        55.000000    NaN    NaN          NaN      0.000000      0.000000
# 75%        63.000000    NaN    NaN          NaN      1.000000      0.000000
# max        90.000000    NaN    NaN          NaN      1.000000      1.000000
#
#         cholesterol_level       obesity  waist_circumference  family_history  \
# count        20000.000000  20000.000000         20000.000000    20000.000000
# unique                NaN           NaN                  NaN             NaN
# top                   NaN           NaN                  NaN             NaN
# freq                  NaN           NaN                  NaN             NaN
# mean           199.185100      0.249600            93.367800        0.294400
# std             39.947344      0.432792            16.266181        0.455784
# min            100.000000      0.000000            27.000000        0.000000
# 25%            172.000000      0.000000            82.000000        0.000000
# 50%            199.000000      0.000000            93.000000        0.000000
# 75%            227.000000      0.000000           104.000000        1.000000
# max            350.000000      1.000000           153.000000        1.000000
#
#         ... blood_pressure_diastolic fasting_blood_sugar cholesterol_hdl  \
# count   ...             20000.000000        20000.000000    20000.000000
# unique  ...                      NaN                 NaN             NaN
# top     ...                      NaN                 NaN             NaN
# freq    ...                      NaN                 NaN             NaN
# mean    ...                79.523250          110.614400       49.531550
# std     ...                 9.977487           27.830186        9.923091
# min     ...                42.000000           70.000000       10.000000
# 25%     ...                73.000000           89.000000       43.000000
# 50%     ...                80.000000          109.000000       49.000000
# 75%     ...                86.000000          130.000000       56.000000
# max     ...               118.000000          228.000000       89.000000
#
#        cholesterol_ldl triglycerides EKG_results  previous_heart_disease  \
# count     20000.000000  20000.000000       20000            20000.000000
# unique             NaN           NaN           2                     NaN
# top                NaN           NaN      Normal                     NaN
# freq               NaN           NaN       16064                     NaN
# mean        129.302650    149.468750         NaN                0.201600
# std          34.779454     49.115999         NaN                0.401205
# min         -18.000000     50.000000         NaN                0.000000
# 25%         106.000000    115.000000         NaN                0.000000
# 50%         130.000000    149.000000         NaN                0.000000
# 75%         153.000000    183.000000         NaN                0.000000
# max         276.000000    347.000000         NaN                1.000000
#
#         medication_usage  participated_in_free_screening  heart_attack
# count       20000.000000                    20000.000000   20000.00000
# unique               NaN                             NaN           NaN
# top                  NaN                             NaN           NaN
# freq                 NaN                             NaN           NaN
# mean            0.498150                        0.603600       0.39480
# std             0.500009                        0.489162       0.48882
# min             0.000000                        0.000000       0.00000
# 25%             0.000000                        0.000000       0.00000
# 50%             0.000000                        1.000000       0.00000
# 75%             1.000000                        1.000000       1.00000
# max             1.000000                        1.000000       1.00000
#
# [11 rows x 28 columns]

# %% [markdown]
# ## Boxplots and histogramas

# %%
column_names_list = df.columns.tolist()
print("List of column names:", column_names_list)

num_cols = df.select_dtypes(include=np.number).columns.tolist()
cat_cols = [c for c in df.columns if c not in num_cols]

for column in num_cols:
    # Boxplot
    plt.figure(figsize=(4, 3))
    df.boxplot(
        column=[column],
        meanline=False,
        showmeans=True,
        return_type="dict"
    )
    plt.title(f"Box plot of {column}")
    plt.ylabel(column)
    plt.show()

    # Histogram
    plt.figure(figsize=(4, 3))
    df[column].hist(bins=10)
    plt.title(f"Histogram of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()
# Out:
# List of column names: ['age', 'gender', 'region', 'income_level', 'hypertension', 'diabetes', 'cholesterol_level', 'obesity', 'waist_circumference', 'family_history', 'smoking_status', 'alcohol_consumption', 'physical_activity', 'dietary_habits', 'air_pollution_exposure', 'stress_level', 'sleep_hours', 'blood_pressure_systolic', 'blood_pressure_diastolic', 'fasting_blood_sugar', 'cholesterol_hdl', 'cholesterol_ldl', 'triglycerides', 'EKG_results', 'previous_heart_disease', 'medication_usage', 'participated_in_free_screening', 'heart_attack']

# %% [markdown]
# ## Correlation analysis
#
# Quantifies which individual features have the strongest linear association with the target. Good sanity check that previous_heart_disease, hypertension, etc... matter.

# %%
data.corr(method = "pearson", numeric_only=True)
# Out:
#                                      age  hypertension  diabetes  \
# age                             1.000000     -0.000512  0.003616
# hypertension                   -0.000512      1.000000 -0.001329
# diabetes                        0.003616     -0.001329  1.000000
# cholesterol_level              -0.003747     -0.001085 -0.001019
# obesity                        -0.001556     -0.002454  0.001720
# waist_circumference             0.001601      0.000724 -0.001773
# family_history                  0.001046      0.000391 -0.001133
# sleep_hours                     0.000996      0.001773  0.001436
# blood_pressure_systolic        -0.001945     -0.002323 -0.004286
# blood_pressure_diastolic        0.001823     -0.000049 -0.002648
# fasting_blood_sugar             0.001721      0.001431  0.002989
# cholesterol_hdl                 0.002060     -0.000334  0.000479
# cholesterol_ldl                 0.000313     -0.000579  0.003871
# triglycerides                   0.001071      0.000362 -0.002776
# previous_heart_disease         -0.000475     -0.004754  0.000584
# medication_usage               -0.003072      0.003349  0.002031
# participated_in_free_screening -0.000620     -0.002905 -0.002566
# heart_attack                    0.105756      0.269261  0.194512
#
#                                 cholesterol_level   obesity  \
# age                                     -0.003747 -0.001556
# hypertension                            -0.001085 -0.002454
# diabetes                                -0.001019  0.001720
# cholesterol_level                        1.000000 -0.000630
# obesity                                 -0.000630  1.000000
# waist_circumference                     -0.000419  0.395426
# family_history                          -0.002900  0.001415
# sleep_hours                              0.001566  0.003177
# blood_pressure_systolic                 -0.000771  0.001068
# blood_pressure_diastolic                 0.001419 -0.000498
# fasting_blood_sugar                     -0.001864  0.002241
# cholesterol_hdl                          0.003067  0.001893
# cholesterol_ldl                          0.000929 -0.001063
# triglycerides                            0.000118 -0.001200
# previous_heart_disease                  -0.004461 -0.001761
# medication_usage                         0.003451 -0.004153
# participated_in_free_screening          -0.000869 -0.003739
# heart_attack                             0.092611  0.171720
#
#                                 waist_circumference  family_history  \
# age                                        0.001601        0.001046
# hypertension                               0.000724        0.000391
# diabetes                                  -0.001773       -0.001133
# cholesterol_level                         -0.000419       -0.002900
# obesity                                    0.395426        0.001415
# waist_circumference                        1.000000        0.000109
# family_history                             0.000109        1.000000
# sleep_hours                                0.002004        0.001150
# blood_pressure_systolic                    0.000340       -0.000897
# blood_pressure_diastolic                   0.002217        0.002180
# fasting_blood_sugar                        0.003899        0.004453
# cholesterol_hdl                           -0.002747       -0.004747
# cholesterol_ldl                           -0.000781        0.002161
# triglycerides                              0.000694       -0.000026
# previous_heart_disease                     0.000844        0.001014
# medication_usage                           0.000056       -0.000015
# participated_in_free_screening            -0.002741        0.002573
# heart_attack                               0.067883        0.001374
#
#                                 sleep_hours  blood_pressure_systolic  \
# age                                0.000996                -0.001945
# hypertension                       0.001773                -0.002323
# diabetes                           0.001436                -0.004286
# cholesterol_level                  0.001566                -0.000771
# obesity                            0.003177                 0.001068
# waist_circumference                0.002004                 0.000340
# family_history                     0.001150                -0.000897
# sleep_hours                        1.000000                -0.000589
# blood_pressure_systolic           -0.000589                 1.000000
# blood_pressure_diastolic           0.003410                -0.002384
# fasting_blood_sugar               -0.001069                -0.001058
# cholesterol_hdl                   -0.002888                -0.005929
# cholesterol_ldl                   -0.001024                 0.001367
# triglycerides                     -0.002672                -0.003280
# previous_heart_disease             0.002168                 0.003781
# medication_usage                   0.003941                 0.000549
# participated_in_free_screening    -0.002101                 0.001929
# heart_attack                       0.000673                -0.001644
#
#                                 blood_pressure_diastolic  fasting_blood_sugar  \
# age                                             0.001823             0.001721
# hypertension                                   -0.000049             0.001431
# diabetes                                       -0.002648             0.002989
# cholesterol_level                               0.001419            -0.001864
# obesity                                        -0.000498             0.002241
# waist_circumference                             0.002217             0.003899
# family_history                                  0.002180             0.004453
# sleep_hours                                     0.003410            -0.001069
# blood_pressure_systolic                        -0.002384            -0.001058
# blood_pressure_diastolic                        1.000000            -0.000854
# fasting_blood_sugar                            -0.000854             1.000000
# cholesterol_hdl                                 0.001408            -0.002455
# cholesterol_ldl                                -0.002969             0.002177
# triglycerides                                  -0.000498             0.006049
# previous_heart_disease                         -0.004296             0.001645
# medication_usage                                0.002096             0.003893
# participated_in_free_screening                  0.000923            -0.002183
# heart_attack                                   -0.000301             0.069826
#
#                                 cholesterol_hdl  cholesterol_ldl  \
# age                                    0.002060         0.000313
# hypertension                          -0.000334        -0.000579
# diabetes                               0.000479         0.003871
# cholesterol_level                      0.003067         0.000929
# obesity                                0.001893        -0.001063
# waist_circumference                   -0.002747        -0.000781
# family_history                        -0.004747         0.002161
# sleep_hours                           -0.002888        -0.001024
# blood_pressure_systolic               -0.005929         0.001367
# blood_pressure_diastolic               0.001408        -0.002969
# fasting_blood_sugar                   -0.002455         0.002177
# cholesterol_hdl                        1.000000        -0.001725
# cholesterol_ldl                       -0.001725         1.000000
# triglycerides                         -0.000933        -0.002760
# previous_heart_disease                -0.000155         0.001334
# medication_usage                       0.000224        -0.001587
# participated_in_free_screening         0.000384         0.003597
# heart_attack                           0.000648         0.000632
#
#                                 triglycerides  previous_heart_disease  \
# age                                  0.001071               -0.000475
# hypertension                         0.000362               -0.004754
# diabetes                            -0.002776                0.000584
# cholesterol_level                    0.000118               -0.004461
# obesity                             -0.001200               -0.001761
# waist_circumference                  0.000694                0.000844
# family_history                      -0.000026                0.001014
# sleep_hours                         -0.002672                0.002168
# blood_pressure_systolic             -0.003280                0.003781
# blood_pressure_diastolic            -0.000498               -0.004296
# fasting_blood_sugar                  0.006049                0.001645
# cholesterol_hdl                     -0.000933               -0.000155
# cholesterol_ldl                     -0.002760                0.001334
# triglycerides                        1.000000                0.001814
# previous_heart_disease               0.001814                1.000000
# medication_usage                     0.003515                0.001303
# participated_in_free_screening       0.000007                0.001936
# heart_attack                        -0.000709                0.274775
#
#                                 medication_usage  \
# age                                    -0.003072
# hypertension                            0.003349
# diabetes                                0.002031
# cholesterol_level                       0.003451
# obesity                                -0.004153
# waist_circumference                     0.000056
# family_history                         -0.000015
# sleep_hours                             0.003941
# blood_pressure_systolic                 0.000549
# blood_pressure_diastolic                0.002096
# fasting_blood_sugar                     0.003893
# cholesterol_hdl                         0.000224
# cholesterol_ldl                        -0.001587
# triglycerides                           0.003515
# previous_heart_disease                  0.001303
# medication_usage                        1.000000
# participated_in_free_screening         -0.002091
# heart_attack                            0.004694
#
#                                 participated_in_free_screening  heart_attack
# age                                                  -0.000620      0.105756
# hypertension                                         -0.002905      0.269261
# diabetes                                             -0.002566      0.194512
# cholesterol_level                                    -0.000869      0.092611
# obesity                                              -0.003739      0.171720
# waist_circumference                                  -0.002741      0.067883
# family_history                                        0.002573      0.001374
# sleep_hours                                          -0.002101      0.000673
# blood_pressure_systolic                               0.001929     -0.001644
# blood_pressure_diastolic                              0.000923     -0.000301
# fasting_blood_sugar                                  -0.002183      0.069826
# cholesterol_hdl                                       0.000384      0.000648
# cholesterol_ldl                                       0.003597      0.000632
# triglycerides                                         0.000007     -0.000709
# previous_heart_disease                                0.001936      0.274775
# medication_usage                                     -0.002091      0.004694
# participated_in_free_screening                        1.000000     -0.003656
# heart_attack                                         -0.003656      1.000000

# %%
corr = df.corr(method="pearson", numeric_only=True)

print("Top correlations with target:")
print(corr[TARGET].abs().sort_values(ascending=False).head(10))
# Out:
# Top correlations with target:
# heart_attack              1.000000
# previous_heart_disease    0.269538
# hypertension              0.267508
# diabetes                  0.189226
# obesity                   0.168322
# smoking_status_Current    0.164638
# age                       0.106216
# cholesterol_level         0.098347
# smoking_status_Never      0.089968
# fasting_blood_sugar       0.073411
# Name: heart_attack, dtype: float64

# %% [markdown]
# ## Finding errors (or outliers) with bi-variate analysis

# %%
# # Let's do regression between a pari of numeric varaibales
# def fit_func(x, a, b):
#     return a*x+b
#
# params = curve_fit(fit_func, data.PIQ,data.FSIQ )  # Here we fit the linear regression and keep the parameters
# print(f"a = {params[0][0]} - b = {params[0][1]}")
#
# # Find errors or outliers
# error = data.FSIQ-[fit_func(x,params[0][0],params[0][1]) for x in data.PIQ]
# print(np.std(error))
# print(error[ error > np.mean(error) + 2 * np.std(error)])
#
# data[data.FSIQ-[fit_func(x,params[0][0],params[0][1]) for x in data.PIQ]==max(data.FSIQ-[fit_func(x,params[0][0],params[0][1]) for x in data.PIQ])]

# %% [markdown]
# s## Bi-variate outlier repair - triglycerides vs cholesterol_level
#
# - Medical data are expensive so we are not going to drop missing values...
# - We keep each record and correct a wrong values with new ones from closest points.

# %%
def lin_fun(x, a, b): return a*x + b
a, b = curve_fit(lin_fun,
                 df["cholesterol_level"],
                 df["triglycerides"])[0]

residuals = df["triglycerides"] - lin_fun(df["cholesterol_level"], a, b)
mask_out = residuals.abs() > 2*residuals.std()

print(f"Replacing {mask_out.sum()} triglyceride outliers by regression prediction")
df.loc[mask_out, "triglycerides"] = lin_fun(df.loc[mask_out, "cholesterol_level"], a, b)
# Out:
# Replacing 986 triglyceride outliers by regression prediction
# /var/folders/03/jf9b8_ss5_ngw7_9xgwlnkg40000gn/T/ipykernel_34975/162030199.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[149.47589071 150.13309194 149.88773682 148.95012973 149.41455193
#  149.39702656 149.63361901 149.15167144 149.38826388 149.38826388
#  148.95889241 149.274349   149.76505925 149.12538339 149.13414607
#  149.75629657 149.74753389 149.65114437 149.37073851 149.72124584
#  149.73000852 149.16043412 148.88879095 149.37073851 149.48465339
#  149.49341608 149.4320773  149.06404461 149.98412633 149.15167144
#  149.51094144 149.53722949 148.7573507  149.59856827 148.68724924
#  148.96765509 149.58104291 149.87021145 149.80887267 149.59856827
#  149.53722949 149.54599218 149.58104291 149.28311168 150.03670243
#  148.98518046 149.45836535 150.08927853 149.16043412 149.4320773
#  149.65114437 149.02023119 149.87897413 149.44960266 149.51970413
#  149.274349   148.87126558 149.07280729 148.66972387 148.66972387
#  149.31816242 149.06404461 149.61609364 149.00270583 149.70372047
#  149.81763535]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[mask_out, "triglycerides"] = lin_fun(df.loc[mask_out, "cholesterol_level"], a, b)

# %%
pd.plotting.scatter_matrix(data[['heart_attack', 'previous_heart_disease', 'hypertension']])
# pd.plotting.scatter_matrix(data[['PIQ', 'VIQ', 'FSIQ']])
print('Scatter matrixes for correlations betwen numeriacal variables ')
# Out:
# Scatter matrixes for correlations betwen numeriacal variables

# %% [markdown]
# ## Handle missing values
#
# - No missing values in the dataset.
# - Only 1 column has missing values but it is not relevant, because column has values called "None" which in pandas means null..

# %%
print("Missing cells per column:")
print(df.isna().sum())
# Out:
# Missing cells per column:
# age                                   0
# gender                                0
# region                                0
# income_level                          0
# hypertension                          0
# diabetes                              0
# cholesterol_level                     0
# obesity                               0
# waist_circumference                   0
# family_history                        0
# smoking_status                        0
# alcohol_consumption               12066
# physical_activity                     0
# dietary_habits                        0
# air_pollution_exposure                0
# stress_level                          0
# sleep_hours                           0
# blood_pressure_systolic               0
# blood_pressure_diastolic              0
# fasting_blood_sugar                   0
# cholesterol_hdl                       0
# cholesterol_ldl                       0
# triglycerides                         0
# EKG_results                           0
# previous_heart_disease                0
# medication_usage                      0
# participated_in_free_screening        0
# heart_attack                          0
# dtype: int64

# %% [markdown]
# ## Standardise numeric features (z‑score)
#
# For every numeric column *x* we compute
#
# \[
# z = \frac{x - \text{mean}(x)}{\text{std}(x)}
# \]
#
# so that each feature now has **mean ≈ 0** and **standard deviation≈1**.
# This “unit‑variance” scaling prevents variables with large raw ranges
# (e.g. cholesterol mg/dL) from swamping small‑range variables (e.g. age years)
# inside the Gaussian Naïve Bayes likelihood calculation and improves numerical stability.

# %%
for col in num_cols:
    df[col] = (df[col] - df[col].mean()) / df[col].std()

# %% [markdown]
# ## Encode categorical variables to numeric
#
# Change categorical variables to numeric using one-hot encoding

# %%
df = pd.get_dummies(df, columns=cat_cols, dtype=np.int8)

# %% [markdown]
# ## Save files for future use
#
# To use the preprocessed data in the future
#
# - heart_preprocessed.npz - for Naive Bayes
# - heart_preprocessed.csv - any other modifications

# %%
# X = df.drop(columns=[TARGET]).values       # NumPy array for Naive Bayes
# y = df[TARGET].values.astype(np.int8)

# np.savez_compressed("heart_preprocessed_naive_bayes.npz", X=X, y=y)
# df.to_csv("heart_preprocessed_naive_bayes.csv", index=False)

# print("Preprocessing finished")
# print("Final feature matrix shape:", X.shape)
# Out:
# Preprocessing finished
# Final feature matrix shape: (20000, 42)
